# %%
# Importando as funções dos arquivos criados
from cadastrar import cadastrar_aluno
from media import calcular_media
from verificar import verificar_situacao

# Executando o sistema
nome, n1, n2 = cadastrar_aluno()
media_final = calcular_media(n1, n2)
situacao = verificar_situacao(media_final)

# Exibindo os resultados conforme o exemplo da tarefa
print(f"\nAluno: {nome}")       # [cite: 22, 26]
print(f"Média: {media_final}")   # [cite: 23, 27]
print(f"Situação: {situacao}")   # [cite: 24, 28]
